# %%
import pandas as pd
import matplotlib.pyplot as plt

datos = pd.read_excel("C:/Users/cappelletti/Desktop/Consumobásico.xlsx",  engine = 'openpyxl')
#print (datos)# me permite imprimir los primeros campos que hay en el archivo.

valores1 = datos[["Aire acondicionado", "Potencia Promedio (en watt)"]] 
#print (valores) 

valores2= datos[["Aire acondicionado", "Consumo en una hora (wh)"]]
#print (valores2)

graf1= valores1.plot.bar( x="Aire acondicionado", y="Potencia Promedio (en watt)")

graf2= valores2.plot.bar( x="Aire acondicionado", y="Consumo en una hora (wh)")
